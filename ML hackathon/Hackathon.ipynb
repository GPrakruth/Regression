# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

# %%
bank = pd.read_csv("train.csv")
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2717: DtypeWarning: Columns (746,835) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
bank.head()
# Out:
#         Col1  Col2          Col3          Col4          Col5          Col6  \
# 0    RIGHGSN     1  1.086711e+04  8.648345e+03  1.576618e+04  2.890466e+04
# 1  RIMHI5ZGP     0  2.584312e+05  2.179633e+05  1.866287e+05  1.866287e+05
# 2  RIHOG1SZU     0  1.459355e+07  1.260060e+07  1.100315e+07  1.010315e+07
# 3  RIHOLMQWU     0  6.727043e+05  8.181116e+05  6.794893e+05  6.794893e+05
# 4  RIHO584ET     0 -1.218742e+06 -3.005361e+06 -1.666241e+05 -2.403574e+06
#
#            Col7          Col8          Col9         Col10   ...     Col2388  \
# 0  5.273655e+03  2.346153e+04  1.285597e+04  2.871509e+04   ...           0
# 1  2.154519e+05  1.923615e+05  1.726538e+05  1.666974e+05   ...           0
# 2  1.879882e+07  1.514035e+07  5.320778e+06  6.906324e+06   ...           0
# 3  8.257254e+05  7.605803e+05  3.577134e+05  4.236612e+05   ...           0
# 4  2.583183e+06  2.086546e+06  5.938358e+06  5.446532e+06   ...           0
#
# ...

# %%
bank.shape
# Out:
# (17521, 2395)

# %%
bank_class =  bank.Col2

# %%
bank_without_class = bank.drop(['Col2'],axis = 1)

# %%
bank_without_class.set_index('Col1')
# Out:
#                    Col3          Col4          Col5          Col6  \
# Col1
# RIGHGSN    1.086711e+04  8.648345e+03  1.576618e+04  2.890466e+04
# RIMHI5ZGP  2.584312e+05  2.179633e+05  1.866287e+05  1.866287e+05
# RIHOG1SZU  1.459355e+07  1.260060e+07  1.100315e+07  1.010315e+07
# RIHOLMQWU  6.727043e+05  8.181116e+05  6.794893e+05  6.794893e+05
# RIHO584ET -1.218742e+06 -3.005361e+06 -1.666241e+05 -2.403574e+06
# RIHR51XD6  3.911176e+06  3.911176e+06  2.995007e+06  2.995007e+06
# RDHD6BX    1.173942e+05  8.499665e+04  8.499665e+04  8.499665e+04
# RS0UVS4    2.582386e+05  2.101529e+05  2.104294e+05  2.416836e+05
# TIWWI0K5   1.463930e+04  1.581304e+04  1.928101e+04  1.598447e+04
# T9VBLOY9   8.405841e+04  3.268636e+04  3.268636e+04  6.535643e+04
# T9LDUOS    8.331730e+04  3.398408e+04  3.469404e+04  5.782340e+04
# T9HRLS5Y   1.541710e+04  1.163359e+04  9.306876e+03  9.306876e+03
# T7LI5YQD   6.348547e+03  5.901796e+03  5.193540e+03  5.193540e+03
# ...

# %%
bank_class = pd.DataFrame(bank_class)

# %%
bank_class.columns = ['Col2']

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=20)

# %%
bank.isnull().sum()
# Out:
# Col1           0
# Col2           0
# Col3           0
# Col4           0
# Col5           0
# Col6           0
# Col7           0
# Col8           0
# Col9           0
# Col10          0
# Col11          0
# Col12          0
# Col13       1249
# Col14       1244
# Col15       1246
# Col16       1243
# Col17       1470
# Col18       2860
# Col19      14759
# Col20      14319
# Col21       1241
# Col22       1244
# Col23       1243
# Col24       1246
# Col25          0
# Col26          0
# Col27        682
# Col28      12260
# Col29          0
# Col30          0
#            ...
# Col2368        0
# Col2369        0
# Col2370        0
# Col2371        0
# Col2372        0
# Col2373        0
# Col2374        0
# Col2375        0
# Col2376        0
# Col2377        0
# Col2378        0
# Col2379        0
# Col2380        0
# Col2381        0
# Col2382        0
# Col2383        0
# Col2384        0
# Col2385        0
# Col2386        0
# Col2387        0
# Col2388        0
# ...

# %%
bank = bank.astype('float')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-64-286d4996bd55> in <module>()
# ----> 1 bank = bank.astype('float')
#
# C:\Program Files\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#      89                 else:
#      90                     kwargs[new_arg_name] = new_arg_value
# ---> 91             return func(*args, **kwargs)
#      92         return wrapper
#      93     return _deprecate_kwarg
#
# C:\Program Files\Anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors, **kwargs)
#    3297         # else, only a single dtype is given
#    3298         new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors,
# -> 3299                                      **kwargs)
#    3300         return self._constructor(new_data).__finalize__(self)
#    3301
#
# ...

# %%
from sklearn.preprocessing import Imputer

# %%
imp = Imputer(missing_values= 'mean')

# %%
bank_without_class = imp.fit_transform(bank_without_class)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-62-331230476e5e> in <module>()
# ----> 1 bank_without_class = imp.fit_transform(bank_without_class)
#
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\base.py in fit_transform(self, X, y, **fit_params)
#     492         if y is None:
#     493             # fit method of arity 1 (unsupervised transformation)
# --> 494             return self.fit(X, **fit_params).transform(X)
#     495         else:
#     496             # fit method of arity 2 (supervised transformation)
#
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\preprocessing\imputation.py in fit(self, X, y)
#     154         if self.axis == 0:
#     155             X = check_array(X, accept_sparse='csc', dtype=np.float64,
# --> 156                             force_all_finite=False)
#     157
#     158             if sparse.issparse(X):
#
# ...

# %%
principalComponents = pca.fit_transform(bank_without_class)
principalDf = pd.DataFrame(data = principalComponents)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-d807e74071cb> in <module>()
# ----> 1 principalComponents = pca.fit_transform(bank_without_class)
#       2 principalDf = pd.DataFrame(data = principalComponents)
#
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\decomposition\pca.py in fit_transform(self, X, y)
#     322
#     323         """
# --> 324         U, S, V = self._fit(X)
#     325         U = U[:, :self.n_components_]
#     326
#
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\decomposition\pca.py in _fit(self, X)
#     344
#     345         X = check_array(X, dtype=[np.float64], ensure_2d=True,
# --> 346                         copy=self.copy)
#     347
#     348         # Handle n_components==None
#
# ...

# %%
bank.dtypes
# Out:
# Col1        object
# Col2         int64
# Col3       float64
# Col4       float64
# Col5       float64
# Col6       float64
# Col7       float64
# Col8       float64
# Col9       float64
# Col10      float64
# Col11      float64
# Col12      float64
# Col13      float64
# Col14      float64
# Col15      float64
# Col16      float64
# Col17      float64
# Col18      float64
# Col19      float64
# Col20      float64
# Col21      float64
# Col22      float64
# Col23      float64
# Col24      float64
# Col25      float64
# Col26      float64
# Col27      float64
# Col28      float64
# Col29        int64
# Col30        int64
#             ...
# Col2368      int64
# Col2369      int64
# Col2370      int64
# Col2371      int64
# Col2372      int64
# Col2373      int64
# Col2374      int64
# Col2375      int64
# Col2376      int64
# Col2377      int64
# Col2378      int64
# Col2379      int64
# Col2380      int64
# Col2381      int64
# Col2382      int64
# Col2383      int64
# ...
